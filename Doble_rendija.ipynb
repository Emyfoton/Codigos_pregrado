# %% [markdown]
# <a href="https://colab.research.google.com/github/Emyfoton/Codigos_pregrado/blob/main/Doble_rendija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ruta = "Doble rendija.xlsx"

filas_deseadas = [3, 4]

df = pd.read_excel(ruta)
df_filtrado = df.iloc[:, filas_deseadas]

print(df_filtrado)
# Out:
#        0.1  1.95
# 0       20  1.83
# 1       40  1.82
# 2       60  1.96
# 3       80  1.87
# 4      100  1.84
# ..     ...   ...
# 568  11380   NaN
# 569  11400   NaN
# 570  11420   NaN
# 571  11440   NaN
# 572  11460   NaN
#
# [573 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

x= df.iloc[:, 3]
y= df.iloc[:, 4]

plt.scatter (x,y, c= "olive")
plt.title("Doble rendija")
plt.xlabel("θ (rad)")
plt.ylabel("Voltaje (V)")
plt.show()

# %%
x2 = df.iloc[:, 0]
y2 = df.iloc[:, 1]

plt.scatter (x2,y2, c= "forestgreen")
plt.title("Rendija Sencilla")
plt.xlabel("θ (rad)")
plt.ylabel("Voltaje (V)")
plt.show()
